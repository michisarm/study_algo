# %% [markdown]
# [프로그래머스 문제풀이](https://school.programmers.co.kr/learn/courses/30/lessons/60061)

# %% [markdown]
# # 문제 설명
# 빙하가 깨지면서 스노우타운에 떠내려 온 "죠르디"는 인생 2막을 위해 주택 건축사업에 뛰어들기로 결심하였습니다. "죠르디"는 기둥과 보를 이용하여 벽면 구조물을 자동으로 세우는 로봇을 개발할 계획인데, 그에 앞서 로봇의 동작을 시뮬레이션 할 수 있는 프로그램을 만들고 있습니다.
# 프로그램은 2차원 가상 벽면에 기둥과 보를 이용한 구조물을 설치할 수 있는데, 기둥과 보는 길이가 1인 선분으로 표현되며 다음과 같은 규칙을 가지고 있습니다.
#
# 기둥은 바닥 위에 있거나 보의 한쪽 끝 부분 위에 있거나, 또는 다른 기둥 위에 있어야 합니다.
# 보는 한쪽 끝 부분이 기둥 위에 있거나, 또는 양쪽 끝 부분이 다른 보와 동시에 연결되어 있어야 합니다.
# 단, 바닥은 벽면의 맨 아래 지면을 말합니다.
#
# 2차원 벽면은 n x n 크기 정사각 격자 형태이며, 각 격자는 1 x 1 크기입니다. 맨 처음 벽면은 비어있는 상태입니다. 기둥과 보는 격자선의 교차점에 걸치지 않고, 격자 칸의 각 변에 정확히 일치하도록 설치할 수 있습니다. 다음은 기둥과 보를 설치해 구조물을 만든 예시입니다.
#
# # 제한사항
# - n은 5 이상 100 이하인 자연수입니다.
# - build_frame의 세로(행) 길이는 1 이상 1,000 이하입니다.
# - build_frame의 가로(열) 길이는 4입니다.
# - build_frame의 원소는 [x, y, a, b]형태입니다.
# - x, y는 기둥, 보를 설치 또는 삭제할 교차점의 좌표이며, [가로 좌표, 세로 좌표] 형태입니다.
# - a는 설치 또는 삭제할 구조물의 종류를 나타내며, 0은 기둥, 1은 보를 나타냅니다.
# - b는 구조물을 설치할 지, 혹은 삭제할 지를 나타내며 0은 삭제, 1은 설치를 나타냅니다.
# - 벽면을 벗어나게 기둥, 보를 설치하는 경우는 없습니다.
# - 바닥에 보를 설치 하는 경우는 없습니다.
# - 구조물은 교차점 좌표를 기준으로 보는 오른쪽, 기둥은 위쪽 방향으로 설치 또는 삭제합니다.
# - 구조물이 겹치도록 설치하는 경우와, 없는 구조물을 삭제하는 경우는 입력으로 주어지지 않습니다.
# - 최종 구조물의 상태는 아래 규칙에 맞춰 return 해주세요.
# - return 하는 배열은 가로(열) 길이가 3인 2차원 배열로, 각 구조물의 좌표를 담고있어야 합니다.
# - return 하는 배열의 원소는 [x, y, a] 형식입니다.
# - x, y는 기둥, 보의 교차점 좌표이며, [가로 좌표, 세로 좌표] 형태입니다.
# - 기둥, 보는 교차점 좌표를 기준으로 오른쪽, 또는 위쪽 방향으로 설치되어 있음을 나타냅니다.
# - a는 구조물의 종류를 나타내며, 0은 기둥, 1은 보를 나타냅니다.
# - return 하는 배열은 x좌표 기준으로 오름차순 정렬하며, x좌표가 같을 경우 y좌표 기준으로 오름차순 정렬해주세요.
# - x, y좌표가 모두 같은 경우 기둥이 보보다 앞에 오면 됩니다.
#
# # 입출력 예
# n	build_frame	result
#
# 5	[[1,0,0,1],[1,1,1,1],[2,1,0,1],[2,2,1,1],[5,0,0,1],[5,1,0,1],[4,2,1,1],[3,2,1,1]]	[[1,0,0],[1,1,1],[2,1,0],[2,2,1],[3,2,1],[4,2,1],[5,0,0],[5,1,0]]
#
# 5	[[0,0,0,1],[2,0,0,1],[4,0,0,1],[0,1,1,1],[1,1,1,1],[2,1,1,1],[3,1,1,1],[2,0,0,0],[1,1,1,0],[2,2,0,1]]	[[0,0,0],[0,1,1],[1,1,1],[2,1,1],[3,1,1],[4,0,0]]
#
# 아홉 번째 작업의 경우, (1, 1)에서 오른쪽에 있는 보를 삭제하면 (2, 1)에서 오른쪽에 있는 보는 조건을 만족하지 않으므로 무시됩니다.<br>
# 열 번째 작업의 경우, (2, 2)에서 위쪽 방향으로 기둥을 세울 경우 조건을 만족하지 않으므로 무시됩니다.

# %% [markdown]
# 출제자의 의도 분석 <br>
# "기둥과 보 설치" 문제의 출제 의도는 다음과 같은 프로그래밍 역량을 평가하기 위함입니다:
#
# 1. 구현 능력
# 복잡한 조건을 코드로 정확히 구현할 수 있는 능력
# 문제에 제시된 규칙을 정확히 이해하고 코드로 옮기는 능력
# 2. 자료구조 활용
# 적절한 자료구조 선택 능력 (리스트 vs 집합)
# 효율적인 데이터 관리 방법에 대한 고민
# 3. 시뮬레이션 능력
# 구조물의 설치/제거를 시뮬레이션하는 능력
# 매 단계마다 전체 구조의 유효성을 검증하는 능력
# 4. 예외 처리
# 다양한 예외 상황을 고려하는 능력
# 구조물 제거 시 발생할 수 있는 연쇄적 유효성 검사
# 5. 문제 해결 전략
# 전체 구조물의 유효성을 매번 검사하는 방식의 효율성 이해
# 불필요한 연산을 최소화하는 방법에 대한 고민
# 6. 정렬과 출력 처리
# 결과를 요구사항에 맞게 정렬하는 능력
# 출력 형식을 정확히 지키는 세심함
# 이 문제는 카카오 코딩 테스트 출제 경향을 반영하여, 실제 업무에서 마주칠 수 있는 복잡한 조건을 가진 문제를 해결하는 능력을 평가하고자 합니다. 특히, 자료구조 선택과 구현 능력, 그리고 효율성에 대한 고민을 유도하는 문제입니다.

# %%
# 첫 번째 셀에서 한 번만 실행
import sys
import os

# 프로젝트 루트 디렉토리를 시스템 경로에 추가
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from utils.performance import measure_performance

# 입력값 예시
# 5, [[1, 0, 0, 1], [1, 1, 1, 1], [2, 1, 0, 1], [2, 2, 1, 1], [5, 0, 0, 1], [5, 1, 0, 1], [4, 2, 1, 1], [3, 2, 1, 1]]

# 입력값
# [x, y, a(0:기둥,1:보), b(0:삭제,1:설치)]
# 출력값
# [x, y, a(0:기둥,1:보)]


# 구조물의 유효성을 검사하는 함수
def build_check(n, answer):
    for x, y, a in answer:
        # 경계 검사
        if x < 0 or x > n or y < 0 or y > n:
            return False
        # 기둥
        if a == 0:
            # 바닥에 있거나, 보의 한쪽 끝에 있거나, 다른 기둥 위에 있어야 함
            if not (
                # 바닥에 있거나
                y == 0
                # 왼쪽 보 위에 있거나
                or [x - 1, y, 1] in answer
                # 오른쪽 보 위에 있거나
                or [x, y, 1] in answer
                # 다른 기둥 위에 있거나
                or [x, y - 1, 0] in answer
            ):
                return False

        # 보
        else:
            # 보는 오른쪽으로 설치되므로 x가 n-1을 초과하면 안됨
            if x >= n:
                return False
            # 한쪽 끝이 기둥 위에 있거나, 양쪽이 다른 보와 연결되어 있어야 함
            if not (
                # 왼쪽 끝이 기둥 위에 있거나
                [x, y - 1, 0] in answer
                # 오른쪽 끝이 기둥 위에 있거나
                or [x + 1, y - 1, 0] in answer
                # 양쪽이 보와 연결되어 있거나
                or ([x - 1, y, 1] in answer and [x + 1, y, 1] in answer)
            ):
                return False
    return True


@measure_performance
def solution(n, build_frame):
    answer = []
    # 한개씩 입력
    for x, y, a, b in build_frame:
        # 설치
        if b == 1:
            print("설치 " + ("기둥" if a == 0 else "보"), "(x:", x, "y:", y, ")")
            # 일단 설치
            # answer.append([x, y, a])
            # 유효하지 않으면 되돌림
            if not build_check(n, answer):
                answer.append([x, y, a])
        # 삭제
        else:
            print("삭제 " + ("기둥" if a == 0 else "보"), "(x:", x, "y:", y, ")")
            # 일단 제거
            answer.remove([x, y, a])
            # 유효하지 않으면 되돌림
            if not build_check(n, answer):
                answer.append([x, y, a])
    # 문제의 정렬 조건에 맞춰 정렬
    # 1. x좌표 오름차순
    # 2. y좌표 오름차순
    # 3. 구조물 타입 오름차순 (0: 기둥, 1: 보)
    answer.sort(key=lambda x: (x[0], x[1], x[2]))
    return answer


# 테스트 케이스
test1 = [
    5,  # n
    [  # build_frame
        [1, 0, 0, 1],
        [1, 1, 1, 1],
        [2, 1, 0, 1],
        [2, 2, 1, 1],
        [5, 0, 0, 1],
        [5, 1, 0, 1],
        [4, 2, 1, 1],
        [3, 2, 1, 1],
    ],
]

# 함수 호출
print("결과", solution(*test1))


# 설치 기둥 (x: 1 y: 0 )
# 설치 보 (x: 1 y: 1 )
# 설치 기둥 (x: 2 y: 1 )
# 설치 보 (x: 2 y: 2 )
# 설치 기둥 (x: 5 y: 0 )
# 설치 기둥 (x: 5 y: 1 )
# 설치 보 (x: 4 y: 2 )
# 설치 보 (x: 3 y: 2 )

# ==================================================
# 함수: solution
# 메모리 사용량: 0.156250 MB
# 실행 시간: 0.335932 ms
# ==================================================

# 결과 [[1, 0, 0], [1, 1, 1], [2, 1, 0], [2, 2, 1], [3, 2, 1], [4, 2, 1], [5, 0, 0], [5, 1, 0]]
# Out:
# 설치 기둥 (x: 1 y: 0 )
# 설치 보 (x: 1 y: 1 )
# 설치 기둥 (x: 2 y: 1 )
# 설치 보 (x: 2 y: 2 )
# 설치 기둥 (x: 5 y: 0 )
# 설치 기둥 (x: 5 y: 1 )
# 설치 보 (x: 4 y: 2 )
# 설치 보 (x: 3 y: 2 )
#
# ...
# 함수: solution
# 메모리 사용량: 0.156250 MB
# 실행 시간: 0.335932 ms
# ...
#
# 결과 [[1, 0, 0], [1, 1, 1], [2, 1, 0], [2, 2, 1], [3, 2, 1], [4, 2, 1], [5, 0, 0], [5, 1, 0]]

# %%
# list

# 테스트 1 〉	통과 (0.10ms, 9.3MB)
# 테스트 2 〉	통과 (0.12ms, 9.17MB)
# 테스트 3 〉	통과 (0.09ms, 9.15MB)
# 테스트 4 〉	통과 (0.30ms, 9.14MB)
# 테스트 5 〉	통과 (0.29ms, 9.32MB)
# 테스트 6 〉	통과 (1.79ms, 9.33MB)
# 테스트 7 〉	통과 (0.02ms, 9.22MB)
# 테스트 8 〉	통과 (0.09ms, 9.18MB)
# 테스트 9 〉	통과 (0.15ms, 9.13MB)
# 테스트 10 〉	통과 (435.29ms, 9.3MB)
# 테스트 11 〉	통과 (2838.64ms, 9.45MB)
# 테스트 12 〉	통과 (334.81ms, 9.34MB)
# 테스트 13 〉	통과 (2731.45ms, 9.63MB)
# 테스트 14 〉	통과 (298.46ms, 9.45MB)
# 테스트 15 〉	통과 (2693.09ms, 9.62MB)
# 테스트 16 〉	통과 (309.61ms, 9.34MB)
# 테스트 17 〉	통과 (2548.25ms, 9.48MB)
# 테스트 18 〉	통과 (1678.20ms, 9.4MB)
# 테스트 19 〉	통과 (1675.08ms, 9.58MB)
# 테스트 20 〉	통과 (1620.59ms, 9.53MB)
# 테스트 21 〉	통과 (2109.93ms, 9.44MB)
# 테스트 22 〉	통과 (1486.05ms, 9.54MB)
# 테스트 23 〉	통과 (1819.90ms, 9.44MB)

# %%
# set

# 테스트 1 〉	통과 (0.03ms, 9.28MB)
# 테스트 2 〉	통과 (0.10ms, 9.22MB)
# 테스트 3 〉	통과 (0.04ms, 9.41MB)
# 테스트 4 〉	통과 (0.10ms, 9.31MB)
# 테스트 5 〉	통과 (0.08ms, 9.29MB)
# 테스트 6 〉	통과 (0.31ms, 9.16MB)
# 테스트 7 〉	통과 (0.02ms, 9.32MB)
# 테스트 8 〉	통과 (0.04ms, 9.18MB)
# 테스트 9 〉	통과 (0.07ms, 9.28MB)
# 테스트 10 〉	통과 (19.06ms, 9.46MB)
# 테스트 11 〉	통과 (54.00ms, 9.6MB)
# 테스트 12 〉	통과 (12.39ms, 9.44MB)
# 테스트 13 〉	통과 (69.99ms, 9.62MB)
# 테스트 14 〉	통과 (21.26ms, 9.42MB)
# 테스트 15 〉	통과 (53.43ms, 9.59MB)
# 테스트 16 〉	통과 (23.43ms, 9.46MB)
# 테스트 17 〉	통과 (46.34ms, 9.49MB)
# 테스트 18 〉	통과 (37.51ms, 9.48MB)
# 테스트 19 〉	통과 (38.44ms, 9.45MB)
# 테스트 20 〉	통과 (39.22ms, 9.49MB)
# 테스트 21 〉	통과 (40.98ms, 9.4MB)
# 테스트 22 〉	통과 (43.35ms, 9.59MB)
# 테스트 23 〉	통과 (48.40ms, 9.55MB)

# %%
def solution(n, build_frame):
    # 현재 설치된 구조물을 저장할 집합 (튜플로 저장)
    answer = set()

    # 구조물의 유효성을 검사하는 함수
    def is_valid(structures):
        for x, y, a in structures:
            if a == 0:  # 기둥인 경우
                if not (
                    y == 0  # 바닥에 있거나
                    or (x - 1, y, 1) in structures  # 왼쪽 보 위에 있거나
                    or (x, y, 1) in structures  # 오른쪽 보 위에 있거나
                    or (x, y - 1, 0) in structures
                ):  # 다른 기둥 위에 있거나
                    return False
            else:  # 보인 경우
                if not (
                    (x, y - 1, 0) in structures  # 왼쪽 끝이 기둥 위에 있거나
                    or (x + 1, y - 1, 0) in structures  # 오른쪽 끝이 기둥 위에 있거나
                    or (
                        (x - 1, y, 1) in structures  # 양쪽이 보와 연결되어 있거나
                        and (x + 1, y, 1) in structures
                    )
                ):
                    return False
        return True

    for x, y, a, b in build_frame:
        item = (x, y, a)  # 튜플로 변환
        if b == 1:  # 설치
            answer.add(item)
            if not is_valid(answer):
                answer.remove(item)
        else:  # 삭제
            answer.remove(item)
            if not is_valid(answer):
                answer.add(item)

    # 결과를 정렬하여 반환 (x, y, a 순으로 정렬)
    return sorted(answer, key=lambda x: (x[0], x[1], x[2]))
